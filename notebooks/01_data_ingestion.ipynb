# %%
import pandas as pd
from pathlib import Path

df = pd.read_csv(Path("data/raw/01_fund_master.csv"))

print("Unique Fund Houses:", df["fund_house"].unique())
print("\nCategories:", df["category"].unique())
print("\nSub-categories:", df["sub_category"].unique())
print("\nRisk Grades:", df["risk_category"].unique())
print("\nTotal schemes:", len(df))

# %% [markdown]
# **Note on missing values — `04_monthly_sip_inflows.csv`:**
# `yoy_growth_pct` has 12 NaN values — expected for the first 12 months
# because there is no prior-year baseline available to calculate YoY growth.
